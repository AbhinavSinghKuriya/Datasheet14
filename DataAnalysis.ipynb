# %%
#imports 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("Student_Performance.csv")
print(df.index)
print("All columns are")
ai=0
for i in df:
    print(ai,i)
    ai+=1
# Out:
# RangeIndex(start=0, stop=10000, step=1)
# All columns are
# 0 Hours Studied
# 1 Previous Scores
# 2 Extracurricular Activities
# 3 Sleep Hours
# 4 Sample Question Papers Practiced
# 5 Performance Index

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.head(n=10)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0           7.75            93.57                        Yes         9.35
# 1           3.79            79.56                         No         4.28
# 2           8.97            46.22                        Yes         6.06
# 3           7.28            52.88                        Yes         5.58
# 4           6.65            84.58                         No         6.51
# 5           2.65            71.83                         No         8.35
# 6           9.00            81.01                        Yes         4.00
# 7           9.00            40.00                        Yes         5.56
# 8           4.30            70.22                         No         7.77
# 9           4.81            95.55                         No         6.17
#
#    Sample Question Papers Practiced  Performance Index
# 0                              0.00              87.23
# ...

# %%
df.sample(n=10)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 5653           7.69            59.09                        Yes         5.59
# 4863           2.97            40.00                        Yes         4.13
# 1854           5.50            72.49                        Yes         5.97
# 6339           1.93            43.74                         No         5.72
# 292            2.12            44.96                        Yes         6.04
# 9712           4.07            40.00                         No         8.62
# 5174           9.00            70.63                         No         8.66
# 1617           5.87            99.22                         No        10.00
# 5139           6.01            59.37                         No         4.95
# 4906           2.26            77.08                         No         6.71
#
#       Sample Question Papers Practiced  Performance Index
# 5653                              5.58              33.49
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  float64
#  1   Previous Scores                   10000 non-null  float64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  float64
#  4   Sample Question Papers Practiced  10000 non-null  float64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 468.9+ KB

# %%
df.isnull()
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0             False            False                       False        False
# 1             False            False                       False        False
# 2             False            False                       False        False
# 3             False            False                       False        False
# 4             False            False                       False        False
# ...             ...              ...                         ...          ...
# 9995          False            False                       False        False
# 9996          False            False                       False        False
# 9997          False            False                       False        False
# 9998          False            False                       False        False
# 9999          False            False                       False        False
#
# ...

# %%
print(df.isnull().sum())
print('no null values')
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64
# no null values

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992931        69.598371      6.584749
# std         2.634294        18.102301      1.809397
# min         1.000000        40.000000      4.000000
# 25%         2.710000        54.627500      4.980000
# 50%         4.980000        69.410000      6.560000
# 75%         7.270000        84.910000      8.050000
# max         9.000000       100.000000     10.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.642358          55.276044
# std                            3.127813          20.636413
# min                            0.000000          10.000000
# 25%                            1.990000          39.660000
# 50%                            4.640000          55.180000
# 75%                            7.120000          70.852500
# ...

# %%
# Plotting only useful columns
grid = sns.pairplot(df,corner=True)

# %%
# For saving the plot
'''

grid.savefig('StudentPerformance.png', dpi=300, bbox_inches='tight')


'''
print('This plot gives us a rough idea of the data')
# Out:
# This plot gives us a rough idea of the data

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
churnplot = sns.pairplot(
            df,
            vars=['Hours Studied', 'Previous Scores','Sleep Hours',
                  'Sample Question Papers Practiced', 'Performance Index'],
            hue='Extracurricular Activities',
            plot_kws={'alpha':0.5},
            corner = True
            )

# %%
'''

churnplot.savefig('ExtraCurricular.png', dpi=300, bbox_inches='tight')

'''

# %%
# Boxplot for outlier detection

numerical_cols = ['Hours Studied', 'Previous Scores','Sleep Hours',
                  'Sample Question Papers Practiced', 'Performance Index']

plt.figure(figsize=(12, 8))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(data=df, y=col, color='skyblue')
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  float64
#  1   Previous Scores                   10000 non-null  float64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  float64
#  4   Sample Question Papers Practiced  10000 non-null  float64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 468.9+ KB
